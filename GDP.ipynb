# %%
import pandas as pd
import numpy as nps
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
df_gdp= pd.read_csv('GDP.csv')

# %%
df_gdp.head()
# Out:
#   Country Name         1960         1961         1962         1963  \
# 0        Aruba          NaN          NaN          NaN          NaN
# 1  Afghanistan  537777811.1  548888895.6  546666677.8  751111191.1
# 2       Angola          NaN          NaN          NaN          NaN
# 3      Albania          NaN          NaN          NaN          NaN
# 4      Andorra          NaN          NaN          NaN          NaN
#
#           1964          1965          1966          1967          1968  ...  \
# 0          NaN           NaN           NaN           NaN           NaN  ...
# 1  800000044.4  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 2          NaN           NaN           NaN           NaN           NaN  ...
# 3          NaN           NaN           NaN           NaN           NaN  ...
# 4          NaN           NaN           NaN           NaN           NaN  ...
#
#            2009          2010          2011          2012          2013  \
# ...

# %%
df_gdp.tail()
# Out:
#      Country Name          1960          1961          1962          1963  \
# 259        Kosovo           NaN           NaN           NaN           NaN
# 260   Yemen, Rep.           NaN           NaN           NaN           NaN
# 261  South Africa  7.575248e+09  7.972841e+09  8.497830e+09  9.423212e+09
# 262        Zambia  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 263      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#              1964          1965          1966          1967          1968  \
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  1.037379e+10  1.133417e+10  1.235475e+10  1.377712e+10  1.489430e+10
# 262  8.394286e+08  1.082857e+09  1.264286e+09  1.368000e+09  1.605857e+09
# 263  1.217138e+09  1.311436e+09  1.281750e+09  1.397002e+09  1.479600e+09
#
#      ...          2009          2010          2011          2012  \
# ...

# %%
df_gdp_all = df_gdp.dropna()

# %%
df_gdp_all
# Out:
#                        Country Name          1960          1961          1962  \
# 11                        Australia  1.857767e+10  1.965394e+10  1.989249e+10
# 12                          Austria  6.592694e+09  7.311750e+09  7.756110e+09
# 14                          Burundi  1.960000e+08  2.030000e+08  2.135000e+08
# 15                          Belgium  1.165872e+10  1.240015e+10  1.326402e+10
# 16                            Benin  2.261956e+08  2.356682e+08  2.364349e+08
# ..                              ...           ...           ...           ...
# 251  St. Vincent and the Grenadines  1.306656e+07  1.399988e+07  1.452488e+07
# 257                           World  1.367630e+12  1.422550e+12  1.527270e+12
# 261                    South Africa  7.575248e+09  7.972841e+09  8.497830e+09
# 262                          Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 263                        Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
# ...

# %%
df = df_gdp_all[(df_gdp_all['Country Name']=='India')| (df_gdp_all['Country Name']=='Pakistan')]
df
# Out:
#     Country Name          1960          1961          1962          1963  \
# 107        India  3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10
# 182     Pakistan  3.707056e+09  4.054599e+09  4.233096e+09  4.540529e+09
#
#              1964          1965          1966          1967          1968  \
# 107  5.648029e+10  5.955486e+10  4.586546e+10  5.013494e+10  5.308546e+10
# 182  5.130408e+09  5.884712e+09  6.466611e+09  7.403822e+09  8.090089e+09
#
#      ...          2009          2010          2011          2012  \
# 107  ...  1.341890e+12  1.675620e+12  1.823050e+12  1.827640e+12
# 182  ...  1.681530e+11  1.774070e+11  2.135870e+11  2.243840e+11
#
#              2013          2014          2015          2016          2017  \
# 107  1.856720e+12  2.039130e+12  2.103590e+12  2.290430e+12  2.652550e+12
# 182  2.312190e+11  2.443610e+11  2.705560e+11  2.786550e+11  3.049520e+11
#
#              2018
# 107  2.726320e+12
# 182  3.125700e+11
#
# [2 rows x 60 columns]

# %%
df= df.set_index('Country Name')

# %%
df1=df.T

df1
# Out:
# Country Name         India      Pakistan
# 1960          3.702988e+10  3.707056e+09
# 1961          3.923244e+10  4.054599e+09
# 1962          4.216148e+10  4.233096e+09
# 1963          4.842192e+10  4.540529e+09
# 1964          5.648029e+10  5.130408e+09
# 1965          5.955486e+10  5.884712e+09
# 1966          4.586546e+10  6.466611e+09
# 1967          5.013494e+10  7.403822e+09
# 1968          5.308546e+10  8.090089e+09
# 1969          5.844800e+10  8.632927e+09
# 1970          6.242248e+10  1.002709e+10
# 1971          6.735099e+10  1.060206e+10
# 1972          7.146320e+10  9.309110e+09
# 1973          8.551527e+10  6.324884e+09
# 1974          9.952590e+10  8.773030e+09
# 1975          9.847280e+10  1.134000e+10
# 1976          1.027170e+11  1.333848e+10
# 1977          1.214870e+11  1.512606e+10
# 1978          1.373000e+11  1.782010e+10
# 1979          1.529920e+11  1.970798e+10
# 1980          1.863250e+11  2.368970e+10
# 1981          1.934910e+11  2.810061e+10
# ...

# %%
df1.plot()
plt.xlabel('Years')
plt.ylabel('GDP in US Dollars $')
plt.title('India & Pakistan GDP in Trillion US$ 1960-2018')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('matplotlip_assignment4_r1.png')

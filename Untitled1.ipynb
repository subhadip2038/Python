# %%
import pandas as pd
energy = pd.read_excel('Energy Indicators1.xls')
energy.head()
# Out:
#           Country Energy Supply Energy Supply per capita  % Renewable
# 0     Afghanistan           321                       10    78.669280
# 1         Albania           102                       35   100.000000
# 2         Algeria          1959                       51     0.551010
# 3  American Samoa           ...                      ...     0.641026
# 4         Andorra             9                      121    88.695650

# %%
energy['Energy Supply'] = energy['Energy Supply'].apply(lambda x: x*1000000)

# %%
energy.head()
# Out:
#           Country                                      Energy Supply  \
# 0     Afghanistan                                          321000000
# 1         Albania                                          102000000
# 2         Algeria                                         1959000000
# 3  American Samoa  .................................................
# 4         Andorra                                            9000000
#
#   Energy Supply per capita  % Renewable
# 0                       10    78.669280
# 1                       35   100.000000
# 2                       51     0.551010
# 3                      ...     0.641026
# 4                      121    88.695650

# %%
GDP = pd.read_csv('world_bank.csv')
GDP.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
GDP = GDP.rename(columns={'Country Name':'Country'})

# %%
GDP.head()
# Out:
#        Country Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
ScimEn= pd.read_excel('scimagojr.xlsx')

# %%
ScimEn.head()
# Out:
#    Rank         Country  Documents  Citable documents  Citations  \
# 0     1           China     193483             192270    1355524
# 1     2   United States     143130             139924    1551044
# 2     3           Japan      41188              40775     357829
# 3     4  United Kingdom      33293              32300     405816
# 4     5           India      32064              31167     268746
#
#    Self-citations  Citations per document  H index
# 0          927458                    7.01      196
# 1          530169                   10.84      301
# 2           93375                    8.69      166
# 3           77019                   12.19      185
# 4           87658                    8.38      153

# %%
energy = energy.set_index('Country')

# %%
ScimEn = ScimEn.set_index('Country')

# %%
GDP = GDP.set_index('Country')

# %%
# Out:
#                 Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# China              1     193483             192270    1355524          927458
# United States      2     143130             139924    1551044          530169
# Japan              3      41188              40775     357829           93375
# United Kingdom     4      33293              32300     405816           77019
# India              5      32064              31167     268746           87658
#
#                 Citations per document  H index
# Country
# China                             7.01      196
# United States                    10.84      301
# Japan                             8.69      166
# United Kingdom                   12.19      185
# India                             8.38      153

# %%
from functools import reduce

# %%
data_frames = [energy, ScimEn, GDP]

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country'],
                                            how='inner'), data_frames)

# %%
df_merged.head()
# Out:
#                                                     Energy Supply  \
# Country
# Afghanistan                                             321000000
# Albania                                                 102000000
# Algeria                                                1959000000
# American Samoa  .................................................
# Andorra                                                   9000000
#
#                Energy Supply per capita  % Renewable  Rank  Documents  \
# Country
# Afghanistan                          10    78.669280   138         14
# Albania                              35   100.000000   120         40
# Algeria                              51     0.551010    41       2254
# American Samoa                      ...     0.641026   171          3
# Andorra                             121    88.695650   175          2
#
#                 Citable documents  Citations  Self-citations  \
# Country
# ...

# %%
df_final= df_merged[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]

# %%
df_final
# Out:
#                 Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Afghanistan      138         14                 13         14               2
# Albania          120         40                 40        266              18
# Algeria           41       2254               2169      18628            3857
# American Samoa   171          3                  3          2               0
# Andorra          175          2                  2         20               0
# ...              ...        ...                ...        ...             ...
# United Kingdom     4      33293              32300     405816           77019
# Uruguay           89        135                133       1432             133
# Uzbekistan       105         80                 79        296              51
# Zambia           119         41                 41         82               8
# Zimbabwe         122         34                 33         53               5
#
# ...

# %%
df=df_final.sort_values(by='Rank', ascending=True)

# %%
df = df_final.head(15)

# %%
df
# Out:
#                      Rank  Documents  Citable documents  Citations  \
# Country
# Afghanistan           138         14                 13         14
# Albania               120         40                 40        266
# Algeria                41       2254               2169      18628
# American Samoa        171          3                  3          2
# Andorra               175          2                  2         20
# Angola                109         69                 69        266
# Antigua and Barbuda   180          2                  2          0
# Argentina              47       1719               1694      18891
# Armenia                92        124                123        895
# Australia              14      14907              14564     196567
# Austria                37       3059               2949      28887
# Azerbaijan             68        658                658       1117
# Bahrain                86        192                188       1709
# ...

# %%
    import pandas as pd
    energy = pd.read_excel('Energy Indicators.xls')
    energy['Energy Supply']= energy['Energy Supply'].apply(lambda x: x*1000000)
    GDP = pd.read_csv('world_bank.csv')
    GDP = GDP.rename(columns={'Country Name':'Country'})
    ScimEn= pd.read_excel('scimagojr.xlsx')
    energy = energy.set_index('Country')
    ScimEn = ScimEn.set_index('Country')
    GDP = GDP.set_index('Country')
    from functools import reduce
    data_frames = [energy, ScimEn, GDP]
    df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country'],
                                            how='inner'), data_frames)
    df_final= df_merged[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
    df= df_final.sort_values(by='Rank', ascending=True)
    df.head(15)
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     193483             192270    1355524
# US                     2     143130             139924    1551044
# Japan                  3      41188              40775     357829
# UK                     4      33293              32300     405816
# India                  5      32064              31167     268746
# Germany                6      27966              27370     278237
# Russian Federation     7      26435              26196      68424
# Canada                 8      26148              25571     395467
# France                 9      19696              19214     238639
# Italy                 10      18773              17987     221652
# South Korea           11      18217              17994     208150
# Iran                  12      15614              15334     160505
# Brazil                13      15332              15132     118483
# ...

# %%
def answer_one():
    import pandas as pd
    energy = pd.read_excel('Energy Indicators.xls')
    energy['Energy Supply'] = energy['Energy Supply'].apply(lambda x: x*1000000)
    GDP = pd.read_csv('world_bank.csv')
    GDP = GDP.rename(columns = {'Country Name':'Country'})
    ScimEn= pd.read_excel('scimagojr.xlsx')
    energy = energy.set_index('Country')
    ScimEn = ScimEn.set_index('Country')
    GDP = GDP.set_index('Country')
    from functools import reduce
    data_frames = [energy, ScimEn, GDP]
    df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country'],
                                            how='inner'), data_frames)
    df_final= df_merged[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
    df= df_final.sort_values(by='Rank', ascending=True)

    return df.head(15)
answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     193483             192270    1355524
# US                     2     143130             139924    1551044
# Japan                  3      41188              40775     357829
# UK                     4      33293              32300     405816
# India                  5      32064              31167     268746
# Germany                6      27966              27370     278237
# Russian Federation     7      26435              26196      68424
# Canada                 8      26148              25571     395467
# France                 9      19696              19214     238639
# Italy                 10      18773              17987     221652
# South Korea           11      18217              17994     208150
# Iran                  12      15614              15334     160505
# Brazil                13      15332              15132     118483
# ...

# %%
df6= df.iloc[5]

# %%
df6.head()
# Out:
# Rank                      6
# Documents             27966
# Citable documents     27370
# Citations            278237
# Self-citations        59495
# Name: Germany, dtype: object

# %%
df6
# Out:
# Rank                                  6
# Documents                         27966
# Citable documents                 27370
# Citations                        278237
# Self-citations                    59495
# Citations per document             9.95
# H index                             166
# Energy Supply               13261000000
# Energy Supply per capita            165
# % Renewable                     17.9015
# 2006                              3e+12
# 2007                           3.44e+12
# 2008                           3.75e+12
# 2009                           3.42e+12
# 2010                           3.42e+12
# 2011                           3.76e+12
# 2012                           3.54e+12
# 2013                           3.75e+12
# 2014                            3.9e+12
# 2015                           3.38e+12
# Name: Germany, dtype: object

# %%
df6['2015']-df6['2006']
# Out:
# 380000000000.0

# %%
df15['avgGDP']= df15[['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']]/10
df15
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avgGDP'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df15 = answer_one()
df15
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     193483             192270    1355524
# US                     2     143130             139924    1551044
# Japan                  3      41188              40775     357829
# UK                     4      33293              32300     405816
# India                  5      32064              31167     268746
# Germany                6      27966              27370     278237
# Russian Federation     7      26435              26196      68424
# Canada                 8      26148              25571     395467
# France                 9      19696              19214     238639
# Italy                 10      18773              17987     221652
# South Korea           11      18217              17994     208150
# Iran                  12      15614              15334     160505
# Brazil                13      15332              15132     118483
# ...

# %%
dfgdp= pd.DataFrame(df15, columns= ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'])
dfgdp
# Out:
#                             2006          2007          2008          2009  \
# Country
# China               2.750000e+12  3.550000e+12  4.590000e+12  5.100000e+12
# US                  1.380000e+13  1.450000e+13  1.470000e+13  1.440000e+13
# Japan               4.530000e+12  4.520000e+12  5.040000e+12  5.230000e+12
# UK                  2.700000e+12  3.080000e+12  2.900000e+12  2.390000e+12
# India               9.400000e+11  1.220000e+12  1.200000e+12  1.340000e+12
# Germany             3.000000e+12  3.440000e+12  3.750000e+12  3.420000e+12
# Russian Federation  9.900000e+11  1.300000e+12  1.660000e+12  1.220000e+12
# Canada              1.320000e+12  1.460000e+12  1.550000e+12  1.370000e+12
# France              2.320000e+12  2.660000e+12  2.920000e+12  2.690000e+12
# Italy               1.940000e+12  2.200000e+12  2.390000e+12  2.190000e+12
# South Korea         1.010000e+12  1.120000e+12  1.000000e+12  9.020000e+11
# ...

# %%
import numpy as np

# %%
dfgdp['avgGDP']= np.mean(dfgdp,axis=1)

# %%
dfgdp.sort_values(by= 'avgGDP', ascending = False)
# Out:
#                             2006          2007          2008          2009  \
# Country
# US                  1.380000e+13  1.450000e+13  1.470000e+13  1.440000e+13
# China               2.750000e+12  3.550000e+12  4.590000e+12  5.100000e+12
# Japan               4.530000e+12  4.520000e+12  5.040000e+12  5.230000e+12
# Germany             3.000000e+12  3.440000e+12  3.750000e+12  3.420000e+12
# UK                  2.700000e+12  3.080000e+12  2.900000e+12  2.390000e+12
# France              2.320000e+12  2.660000e+12  2.920000e+12  2.690000e+12
# Italy               1.940000e+12  2.200000e+12  2.390000e+12  2.190000e+12
# Brazil              1.110000e+12  1.400000e+12  1.700000e+12  1.670000e+12
# Russian Federation  9.900000e+11  1.300000e+12  1.660000e+12  1.220000e+12
# Canada              1.320000e+12  1.460000e+12  1.550000e+12  1.370000e+12
# India               9.400000e+11  1.220000e+12  1.200000e+12  1.340000e+12
# ...

# %%
capita = pd.DataFrame(df15, columns= ['Energy Supply per capita'])

# %%
capita
# Out:
#                    Energy Supply per capita
# Country
# China                                    93
# US                                      286
# Japan                                   149
# UK                                      124
# India                                    26
# Germany                                 165
# Russian Federation                      214
# Canada                                  296
# France                                  166
# Italy                                   109
# South Korea                             221
# Iran                                    119
# Brazil                                   59
# Australia                               231
# Spain                                   106

# %%
mcapita = np.mean(capita, axis=0)

# %%
mcapita
# Out:
# Energy Supply per capita    157.6
# dtype: float64

# %%
renew = pd.DataFrame(df15, columns= ['% Renewable'])
renew
# Out:
#                     % Renewable
# Country
# China                 19.754910
# US                    11.570980
# Japan                 10.232820
# UK                    10.600470
# India                 14.969080
# Germany               17.901530
# Russian Federation    17.288680
# Canada                61.945430
# France                17.020280
# Italy                 33.667230
# South Korea            2.279353
# Iran                   5.707721
# Brazil                69.648030
# Australia             11.810810
# Spain                 37.968590

# %%
renew['Total']= renew['% Renewable'].sum()
renew['ratio']= renew['% Renewable']/renew['Total']
renew
# Out:
#                     % Renewable       Total     ratio
# Country
# China                 19.754910  342.365914  0.057701
# US                    11.570980  342.365914  0.033797
# Japan                 10.232820  342.365914  0.029889
# UK                    10.600470  342.365914  0.030962
# India                 14.969080  342.365914  0.043722
# Germany               17.901530  342.365914  0.052288
# Russian Federation    17.288680  342.365914  0.050498
# Canada                61.945430  342.365914  0.180933
# France                17.020280  342.365914  0.049714
# Italy                 33.667230  342.365914  0.098337
# South Korea            2.279353  342.365914  0.006658
# Iran                   5.707721  342.365914  0.016671
# Brazil                69.648030  342.365914  0.203432
# Australia             11.810810  342.365914  0.034498
# Spain                 37.968590  342.365914  0.110901

# %%
renew.sort_values(by = 'ratio', ascending = False)
# Out:
#                     % Renewable       Total     ratio
# Country
# Brazil                69.648030  342.365914  0.203432
# Canada                61.945430  342.365914  0.180933
# Spain                 37.968590  342.365914  0.110901
# Italy                 33.667230  342.365914  0.098337
# China                 19.754910  342.365914  0.057701
# Germany               17.901530  342.365914  0.052288
# Russian Federation    17.288680  342.365914  0.050498
# France                17.020280  342.365914  0.049714
# India                 14.969080  342.365914  0.043722
# Australia             11.810810  342.365914  0.034498
# US                    11.570980  342.365914  0.033797
# UK                    10.600470  342.365914  0.030962
# Japan                 10.232820  342.365914  0.029889
# Iran                   5.707721  342.365914  0.016671
# South Korea            2.279353  342.365914  0.006658

# %%
ratio = renew.sort_values(by = 'ratio', ascending = False)
ratio['ratio']
ratio['% Renewable']
# Out:
# Country
# Brazil                69.648030
# Canada                61.945430
# Spain                 37.968590
# Italy                 33.667230
# China                 19.754910
# Germany               17.901530
# Russian Federation    17.288680
# France                17.020280
# India                 14.969080
# Australia             11.810810
# US                    11.570980
# UK                    10.600470
# Japan                 10.232820
# Iran                   5.707721
# South Korea            2.279353
# Name: % Renewable, dtype: float64

# %%
ratio.idxmax()
ratio.max()
# Out:
# % Renewable     69.648030
# Total          342.365914
# ratio            0.203432
# dtype: float64

# %%
citation = pd.DataFrame(df15, columns = ['Self-citations','Citations'])

# %%
citation
# Out:
#                     Self-citations  Citations
# Country
# China                       927458    1355524
# US                          530169    1551044
# Japan                        93375     357829
# UK                           77019     405816
# India                        87658     268746
# Germany                      59495     278237
# Russian Federation           29544      68424
# Canada                       74112     395467
# France                       48462     238639
# Italy                        54282     221652
# South Korea                  39811     208150
# Iran                         51493     160505
# Brazil                       28818     118483
# Australia                    34134     196567
# Spain                        42632     233955

# %%
citation['ratio']= citation['Self-citations']/citation['Citations']
citation
# Out:
#                     Self-citations  Citations     ratio
# Country
# China                       927458    1355524  0.684206
# US                          530169    1551044  0.341814
# Japan                        93375     357829  0.260949
# UK                           77019     405816  0.189788
# India                        87658     268746  0.326174
# Germany                      59495     278237  0.213828
# Russian Federation           29544      68424  0.431778
# Canada                       74112     395467  0.187404
# France                       48462     238639  0.203077
# Italy                        54282     221652  0.244897
# South Korea                  39811     208150  0.191261
# Iran                         51493     160505  0.320819
# Brazil                       28818     118483  0.243225
# Australia                    34134     196567  0.173651
# Spain                        42632     233955  0.182223

# %%
cmax= citation.sort_values( by='ratio', ascending = False)

# %%
cmax['ratio']
# Out:
# Country
# China                 0.684206
# Russian Federation    0.431778
# US                    0.341814
# India                 0.326174
# Iran                  0.320819
# Japan                 0.260949
# Italy                 0.244897
# Brazil                0.243225
# Germany               0.213828
# France                0.203077
# South Korea           0.191261
# UK                    0.189788
# Canada                0.187404
# Spain                 0.182223
# Australia             0.173651
# Name: ratio, dtype: float64

# %%
    import pandas as pd
    df15 = answer_one()
    percapita = citation = pd.DataFrame(df15, columns = ['Energy Supply','Energy Supply per capita'])
    percapita['population']= percapita['Energy Supply']/percapita['Energy Supply per capita']

# %%
percapita
# Out:
#                    Energy Supply Energy Supply per capita   population
# Country
# China               127191000000                       93  1.36765e+09
# US                   90838000000                      286  3.17615e+08
# Japan                18984000000                      149  1.27409e+08
# UK                    7920000000                      124   6.3871e+07
# India                33195000000                       26  1.27673e+09
# Germany              13261000000                      165  8.03697e+07
# Russian Federation   30709000000                      214    1.435e+08
# Canada               10431000000                      296  3.52399e+07
# France               10597000000                      166  6.38373e+07
# Italy                 6530000000                      109  5.99083e+07
# South Korea          11007000000                      221  4.98054e+07
# Iran                  9172000000                      119  7.70756e+07
# ...

# %%
pmax = percapita.sort_values(by = 'population', ascending = False)
pmax['population']
# Out:
# Country
# China                 1.36765e+09
# India                 1.27673e+09
# US                    3.17615e+08
# Brazil                2.05915e+08
# Russian Federation      1.435e+08
# Japan                 1.27409e+08
# Germany               8.03697e+07
# Iran                  7.70756e+07
# UK                     6.3871e+07
# France                6.38373e+07
# Italy                 5.99083e+07
# South Korea           4.98054e+07
# Spain                 4.64434e+07
# Canada                3.52399e+07
# Australia              2.3316e+07
# Name: population, dtype: object

# %%
country = pmax['population']

country
# Out:
# Country
# China                 1.36765e+09
# India                 1.27673e+09
# US                    3.17615e+08
# Brazil                2.05915e+08
# Russian Federation      1.435e+08
# Japan                 1.27409e+08
# Germany               8.03697e+07
# Iran                  7.70756e+07
# UK                     6.3871e+07
# France                6.38373e+07
# Italy                 5.99083e+07
# South Korea           4.98054e+07
# Spain                 4.64434e+07
# Canada                3.52399e+07
# Australia              2.3316e+07
# Name: population, dtype: object

# %%
d
# Out:
# 1367645161.2903225

# %%
idx = (country).argsort()[:3]

# %%
idx
# Out:
# Country
# China    14
# India    13
# US       12
# Name: population, dtype: int64

# %%
idx.idxmin()
# Out:
# 'US'

# %%
df15 =pd.DataFrame(df15, columns =['Energy Supply','Energy Supply per capita','Citable documents'])
df15['population'] = df15['Energy Supply']/df15['Energy Supply per capita']
df15['Citable docs per Capita'] = df15['Citable documents'] / df15['population']
dfcorr = pd.DataFrame(df15, columns =['Energy Supply per capita','Citable docs per Capita'])
dfcorr
# Out:
#                    Energy Supply per capita Citable docs per Capita
# Country
# China                                    93             0.000140585
# US                                      286             0.000440545
# Japan                                   149             0.000320031
# UK                                      124             0.000505707
# India                                    26             2.44116e-05
# Germany                                 165             0.000340551
# Russian Federation                      214             0.000182551
# Canada                                  296             0.000725627
# France                                  166             0.000300984
# Italy                                   109             0.000300242
# South Korea                             221             0.000361286
# Iran                                    119             0.000198947
# Brazil                                   59             7.34865e-05
# ...

# %%
 pd.__version__
# Out:
# '0.25.1'

# %%
import numpy as np
import matplotlib.pyplot as plt

def on_press(event):
    if event.inaxes is None: return
    for line in event.inaxes.lines:
        if event.key=='t':
            visible = line.get_visible()
            line.set_visible(not visible)
    event.inaxes.figure.canvas.draw()

fig, ax = plt.subplots(1)

fig.canvas.mpl_connect('key_press_event', on_press)

ax.plot(np.random.rand(2, 20))

plt.show()

# %%
on_press(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-384-6cb58623a400> in <module>
# ----> 1 on_press(t)
#
# NameError: name 't' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x, 100)
plt.title(r'Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram.png')
plt.show()

# %%
import numpy as np

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear',)
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic' )

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
# plain text
plt.title('alpha > beta')
# Out:
# Text(0.5, 1.0, 'alpha > beta')

# %%
# math text
plt.title(r'$\alpha > \beta$')
# Out:
# Text(0.5, 1.0, '$\\alpha > \\beta$')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

#TODO: remove all the ticks (both axes), and tick labels on the Y axis

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# TODO: remove the frame of the chart

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
#plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.show()

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
plt.plot(x, y,'mo')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['path.simplify_threshold'] = 1.0

# Setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.logspace(1,np.log10(50000), 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

mpl.rcParams['agg.path.chunksize'] = 0
plt.plot(y)
plt.show()

mpl.rcParams['agg.path.chunksize'] = 10000
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5,6], 'o')
plt.ylabel("One example plot")
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

plt.show()

# %%
lines = plt.plot([1, 2, 3])

# %%
plt.setp(lines)
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `.Transform`) | `.Patch` | None]
#   color or c: color
#   contains: callable
#   dash_capstyle: {'butt', 'round', 'projecting'}
#   dash_joinstyle: {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
# ...

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(2)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 145841.99,
        'Will LLC': 124437.60}
group_data = list(data.values())
group_names = list(data.keys())
mean = np.mean(group_data)

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('ggplot')

# %%
plt.barh(group_names, group_data)
plt.title("Company Revenue")
plt.xlabel("Total Revenue $")
plt.ylabel("Company Name")
# Out:
# Text(0, 0.5, 'Company Name')

# %%
plt.style.use('seaborn-bright')
plt.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.use('tableau-colorblind10')
plt.barh(group_names, group_data)
plt.title("Company Revenue")
plt.xlabel("Total Revenue $")
plt.ylabel("Company Name")
# Out:
# Text(0, 0.5, 'Company Name')

# %%
import matplotlib.pyplot as plt
import mplleaflet
import pandas as pd

work_hash='9bb07a5e09b09da62cd27426972a16f29a246bec415aa14abce9e3a1'
cstr_MetaFileName='data/C2A2_data/BinSize_d{}.csv'.format(25)
cstrWorkFile='data/C2A2_data/BinnedCsvs_d{}/{}.csv'.format(25, work_hash)

def make_dfMeta(hashid):
    df = pd.read_csv(cstr_MetaFileName)
    return df[df['hash'] == hashid]

def leaflet_plot_stations(binsize, hashid):

    #dfMeta = pd.read_csv('data/C2A2_data/BinSize_d{}.csv'.format(binsize))
    
   
    #print(df[df['NAME'].str.contains('MOSCOW') & df['STATE'].isnull()])
    #hshWork=df[df['NAME'].str.contains('MOSCOW') & df['STATE'].isnull()]
    #print('hash=', hshWork['hash'].values[0])
    
    station_locations_by_hash = make_dfMeta(work_hash)

    #print(station_locations_by_hash.head(20))
    
    lons = station_locations_by_hash['LONGITUDE'].tolist()
    lats = station_locations_by_hash['LATITUDE'].tolist()

    plt.figure(figsize=(10,10))

    plt.scatter(lons, lats, c='r', alpha=0.7, s=100)

    return mplleaflet.display()

leaflet_plot_stations(25,work_hash)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-460-e0727027de02> in <module>
#      33     return mplleaflet.display()
#      34
# ---> 35 leaflet_plot_stations(25,work_hash)
#
# <ipython-input-460-e0727027de02> in leaflet_plot_stations(binsize, hashid)
#      20     #print('hash=', hshWork['hash'].values[0])
#      21
# ---> 22     station_locations_by_hash = make_dfMeta(work_hash)
#      23
#      24     #print(station_locations_by_hash.head(20))
#
# <ipython-input-460-e0727027de02> in make_dfMeta(hashid)
#       8
#       9 def make_dfMeta(hashid):
# ---> 10     df = pd.read_csv(cstr_MetaFileName)
#      11     return df[df['hash'] == hashid]
#      12
#
# ...

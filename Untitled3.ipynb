# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
df= pd.read_excel('berth.xlsx')

# %%
df
# Out:
#      yr_mn  S3_occupancy  S4_occupancy
# 0   Jan-17      0.262581      0.494516
# 1   Feb-17      0.511786      0.315000
# 2   Mar-17      0.324839      0.264194
# 3   Apr-17      0.358000      0.683000
# 4   May-17      0.530000      0.332581
# 5   Jun-17      0.322000      0.478333
# 6   Jul-17      0.404839      0.650000
# 7   Aug-17      0.502258      0.602581
# 8   Sep-17      0.282667      0.490333
# 9   Oct-17      0.859355      0.323548
# 10  Nov-17      0.321000      0.338333
# 11  Dec-17      0.278387      0.509677
# 12  Jan-18      0.641935      0.230968
# 13  Feb-18      0.153571      0.257143
# 14  Mar-18      0.449032      0.254839
# 15  Apr-18      0.265333      0.187667
# 16  May-18      0.388387      0.394839
# 17  Jun-18      0.506000      0.631667
# 18  Jul-18      0.545161      0.504839
# 19  Aug-18      0.594516      0.706129
# 20  Sep-18      0.694333      0.505333
# 21  Oct-18      0.641935      0.496774
# 22  Nov-18      0.687333      0.727667
# ...

# %%
s3 = df['S3_occupancy']
s4= df['S4_occupancy']

# %%
sns.jointplot(s3,s4, alpha=0.4, space=0);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 = pd.read_csv('consumerpriceindex.csv')

# %%
df2.head()
# Out:
#        Country  Year      Series     Value
# 0  Afghanistan  2005  CP_General    71.141
# 1  Afghanistan  2010  CP_General       100
# 2  Afghanistan  2015  CP_General  132.1177
# 3  Afghanistan  2016  CP_General  137.9046
# 4  Afghanistan  2017  CP_General  144.7692

# %%
df1 = pd.read_csv('agriculturalindex.csv')

# %%
df1.head()
# Out:
#        Country  Year                         Series  Value
# 0  Afghanistan  1975  Agricultural production Index   80.7
# 1  Afghanistan  1985  Agricultural production Index   69.1
# 2  Afghanistan  1995  Agricultural production Index   85.6
# 3  Afghanistan  2005  Agricultural production Index  106.6
# 4  Afghanistan  2010  Agricultural production Index  116.2

# %%
df1.plot(kind='box');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_excel('Data_Extract_From_Sustainable_Energy_for_All.xlsx')

# %%
df.head()
# Out:
#   Country Name Country Code  Time Time Code  2.1_ACCESS.CFT.TOT  \
# 0  Afghanistan          AFG  1990    YR1990                 NaN
# 1  Afghanistan          AFG  1991    YR1991                 NaN
# 2  Afghanistan          AFG  1992    YR1992                 NaN
# 3  Afghanistan          AFG  1993    YR1993                 NaN
# 4  Afghanistan          AFG  1994    YR1994                 NaN
#
#    1.2_ACCESS.ELECTRICITY.RURAL  1.1_ACCESS.ELECTRICITY.TOT  \
# 0                           NaN                        0.01
# 1                           NaN                        0.01
# 2                           NaN                        0.01
# 3                           NaN                        0.01
# 4                           NaN                        0.01
#
#    1.3_ACCESS.ELECTRICITY.URBAN  6.1_PRIMARY.ENERGY.INTENSITY  \
# 0                     52.036976                      1.884113
# 1                     53.809837                      1.995913
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code  Time Time Code  2.1_ACCESS.CFT.TOT  \
# 6988     Zimbabwe          ZWE  2012    YR2012               30.02
# 6989     Zimbabwe          ZWE  2013    YR2013               29.88
# 6990     Zimbabwe          ZWE  2014    YR2014               29.63
# 6991     Zimbabwe          ZWE  2015    YR2015               29.36
# 6992     Zimbabwe          ZWE  2016    YR2016               29.05
#
#       1.2_ACCESS.ELECTRICITY.RURAL  1.1_ACCESS.ELECTRICITY.TOT  \
# 6988                     12.981644                   36.728878
# 6989                     13.669918                   37.076813
# 6990                      9.800000                   32.300000
# 6991                      9.700000                   33.700000
# 6992                     15.575584                   38.145138
#
#       1.3_ACCESS.ELECTRICITY.URBAN  6.1_PRIMARY.ENERGY.INTENSITY  \
# 6988                     85.306770                     18.437246
# ...

# %%
df1 = df.drop(columns =['Time Code','Country Code'])

# %%
df1.head()
# Out:
#   Country Name  Time  2.1_ACCESS.CFT.TOT  1.2_ACCESS.ELECTRICITY.RURAL  \
# 0  Afghanistan  1990                 NaN                           NaN
# 1  Afghanistan  1991                 NaN                           NaN
# 2  Afghanistan  1992                 NaN                           NaN
# 3  Afghanistan  1993                 NaN                           NaN
# 4  Afghanistan  1994                 NaN                           NaN
#
#    1.1_ACCESS.ELECTRICITY.TOT  1.3_ACCESS.ELECTRICITY.URBAN  \
# 0                        0.01                     52.036976
# 1                        0.01                     53.809837
# 2                        0.01                     55.582523
# 3                        0.01                     57.354179
# 4                        0.01                     59.123775
#
#    6.1_PRIMARY.ENERGY.INTENSITY  4.1.2_REN.ELECTRICITY.OUTPUT  \
# 0                      1.884113                         764.0
# ...

# %%
df1.tail()
# Out:
#      Country Name  Time  2.1_ACCESS.CFT.TOT  1.2_ACCESS.ELECTRICITY.RURAL  \
# 6988     Zimbabwe  2012               30.02                     12.981644
# 6989     Zimbabwe  2013               29.88                     13.669918
# 6990     Zimbabwe  2014               29.63                      9.800000
# 6991     Zimbabwe  2015               29.36                      9.700000
# 6992     Zimbabwe  2016               29.05                     15.575584
#
#       1.1_ACCESS.ELECTRICITY.TOT  1.3_ACCESS.ELECTRICITY.URBAN  \
# 6988                   36.728878                     85.306770
# 6989                   37.076813                     85.351479
# 6990                   32.300000                     83.400000
# 6991                   33.700000                     81.200000
# 6992                   38.145138                     85.500160
#
#       6.1_PRIMARY.ENERGY.INTENSITY  4.1.2_REN.ELECTRICITY.OUTPUT  \
# 6988                     18.437246                        5558.0
# ...

# %%
df2= df1.set_index(['Country Name', 'Time'])
df2.head(20)
# Out:
#                    2.1_ACCESS.CFT.TOT  1.2_ACCESS.ELECTRICITY.RURAL  \
# Country Name Time
# Afghanistan  1990                 NaN                           NaN
#              1991                 NaN                           NaN
#              1992                 NaN                           NaN
#              1993                 NaN                           NaN
#              1994                 NaN                           NaN
#              1995                 NaN                           NaN
#              1996                 NaN                           NaN
#              1997                 NaN                           NaN
#              1998                 NaN                           NaN
#              1999                 NaN                           NaN
#              2000                8.80                           NaN
#              2001                9.51                           NaN
# ...

# %%
filter_country = ['India','Pakistan', 'Bhutan', 'Bangladesh','Nepal','Maldives','Srilanka']
filter_country
# Out:
# ['India', 'Pakistan', 'Bhutan', 'Bangladesh', 'Nepal', 'Maldives', 'Srilanka']

# %%
df3 = df2.loc[['India','Pakistan', 'Bhutan', 'Bangladesh','Nepal','Maldives','Srilanka']]

# %%
df3
# Out:
#                    2.1_ACCESS.CFT.TOT  1.2_ACCESS.ELECTRICITY.RURAL  \
# Country Name Time
# Bangladesh   1990                 NaN                           NaN
#              1991                 NaN                      4.570000
#              1992                 NaN                           NaN
#              1993                 NaN                      1.753809
#              1994                 NaN                     10.400000
# ...                               ...                           ...
# Pakistan     2012               38.13                     89.526820
#              2013               39.47                     90.500000
#              2014               40.74                     94.102028
#              2015               42.13                     90.370000
#              2016               43.32                     98.807674
#
#                    1.1_ACCESS.ELECTRICITY.TOT  1.3_ACCESS.ELECTRICITY.URBAN  \
# Country Name Time
# ...

# %%
df_bang = df3.loc['Bangladesh']

# %%
df_bang.reset_index()
# Out:
#     Time  2.1_ACCESS.CFT.TOT  1.2_ACCESS.ELECTRICITY.RURAL  \
# 0   1990                 NaN                           NaN
# 1   1991                 NaN                      4.570000
# 2   1992                 NaN                           NaN
# 3   1993                 NaN                      1.753809
# 4   1994                 NaN                     10.400000
# 5   1995                 NaN                      6.760987
# 6   1996                 NaN                      9.258692
# 7   1997                 NaN                     15.100000
# 8   1998                 NaN                     14.227780
# 9   1999                 NaN                     16.691406
# 10  2000                7.24                     20.500000
# 11  2001                7.78                     21.490879
# 12  2002                8.16                     23.733379
# 13  2003                8.73                     25.979646
# 14  2004                9.20                     30.400000
# ...

# %%
index=df_bang.index.tolist()
values = df_bang['2.1_ACCESS.CFT.TOT']

plt.bar(index, values)
# Out:
# <BarContainer object of 27 artists>

# %%
index
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

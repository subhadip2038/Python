# %% [markdown]
# # Pandas for Data Science

# %%
import pandas as pd
s = pd.Series([3,-5,7,4], index = ['a','b','c','d'])

# %% [markdown]
# # Calling a single dimentional Array

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # Create a two dimentional array

# %%
data = {'Country': ['Belgium','India','Brazil'],'Capital':['Brussels','New Delhi','Brasilia'],
       'Population': [11190846,1303171035,207847528]}
df= pd.DataFrame(data, columns = ['Country','Capital','Population'])

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# # Selection of values

# %%
s['b']
# Out:
# -5

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasilia   207847528

# %%
df[0:2]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
df[:]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df[2:2]
# Out:
# Empty DataFrame
# Columns: [Country, Capital, Population]
# Index: []

# %%
df[0:2]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
df.iloc[[0],[0]]
# Out:
#    Country
# 0  Belgium

# %%
df.loc[[0],['Country']]
# Out:
#    Country
# 0  Belgium

# %%
df.ix[2, 'Capital']
# Out:
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'Brasilia'

# %%
df['Country']
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %%
df.loc[[0],['Country']]
# Out:
#    Country
# 0  Belgium

# %%
df.ix[[2],['Capital']]
# Out:
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#     Capital
# 2  Brasilia

# %%
df.Country
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %%
df.Capital
# Out:
# 0     Brussels
# 1    New Delhi
# 2     Brasilia
# Name: Capital, dtype: object

# %%
df.Population
# Out:
# 0      11190846
# 1    1303171035
# 2     207847528
# Name: Population, dtype: int64

# %%
df.Country
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %%
df[:2]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
df[1:2]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %%
df[2:3]
# Out:
#   Country   Capital  Population
# 2  Brazil  Brasilia   207847528

# %%
df[:3]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df[2:]
# Out:
#   Country   Capital  Population
# 2  Brazil  Brasilia   207847528

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasilia   207847528

# %%
import pandas as pd
energy = pd.read_excel('Energy Indicators.xls', header= 16,usecols="C:F")

# %%
energy.head()
# Out:
#           Country Energy Supply Energy Supply per capita % Renewable
# 1     Afghanistan           321                       10     78.6693
# 2         Albania           102                       35         100
# 3         Algeria          1959                       51     0.55101
# 4  American Samoa           ...                      ...    0.641026
# 5         Andorra             9                      121     88.6957

# %%
energy.tail(50)
# Out:
#                                                Country Energy Supply  \
# 216                        United Republic of Tanzania           994
# 217                         United States of America20         90838
# 218                       United States Virgin Islands           ...
# 219                                            Uruguay           196
# 220                                         Uzbekistan          1798
# 221                                            Vanuatu             3
# 222                 Venezuela (Bolivarian Republic of)          2871
# 223                                           Viet Nam          2554
# 224                          Wallis and Futuna Islands             0
# 225                                              Yemen           344
# 226                                             Zambia           400
# 227                                           Zimbabwe           480
# 228                                                NaN           NaN
# 229                                                NaN           NaN
# 230                                                NaN           NaN
# 231                                                NaN           NaN
# 232                                                NaN           NaN
# 233                                                NaN           NaN
# 234                                                NaN           NaN
# 235                 Excludes the overseas territories.           NaN
# 236  Data exclude Hong Kong and Macao Special Admin...           NaN
# 237  Data on kerosene-type jet fuel include aviatio...           NaN
# 238  For confidentiality reasons, data on coal and ...           NaN
# 239      Data exclude Greenland and the Danish Faroes.           NaN
# 240  Data include Monaco, and exclude the following...           NaN
# 241  Data for kerosene-type jet fuel include other ...           NaN
# 242               Data include Timor-Leste until 2001.           NaN
# 243         Data include San Marino and the Holy See.            NaN
# 244                              Data include Okinawa.           NaN
# 245  The data for crude oil production include 50 p...           NaN
# 246  Data exclude Suriname and the Netherlands Anti...           NaN
# 247               Data include the Azores and Madeira.           NaN
# 248  Data for crude oil production include 50 per c...           NaN
# 249             Data exclude Kosovo from 2000 onwards.           NaN
# 250                   Data include the Canary Islands.           NaN
# 251     Data include Liechtenstein for oil statistics.           NaN
# 252  For confidentiality reasons, data on the follo...           NaN
# 253  Shipments of coal and oil to Jersey, Guernsey ...           NaN
# 254  Includes the 50 states and the District of Col...           NaN
# 255                                                NaN           NaN
# 256                                                NaN           NaN
# 257                                                NaN           NaN
# 258                                                NaN           NaN
# 259                                                NaN           NaN
# 260                                                NaN           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 263                                                NaN           NaN
# 264                                                NaN           NaN
# 265                                                NaN           NaN
#
#     Energy Supply per capita % Renewable
# 216                       20     31.0728
# 217                      286      11.571
# 218                      ...           0
# 219                       58      71.605
# 220                       62     21.3284
# 221                       10     14.7059
# 222                       95     67.8345
# 223                       28     45.3215
# 224                       26           0
# 225                       13           0
# 226                       26     99.7147
# 227                       32     52.5361
# 228                      NaN         NaN
# 229                      NaN         NaN
# 230                      NaN         NaN
# 231                      NaN         NaN
# 232                      NaN         NaN
# 233                      NaN         NaN
# 234                      NaN         NaN
# 235                      NaN         NaN
# 236                      NaN         NaN
# 237                      NaN         NaN
# 238                      NaN         NaN
# 239                      NaN         NaN
# 240                      NaN         NaN
# 241                      NaN         NaN
# 242                      NaN         NaN
# 243                      NaN         NaN
# 244                      NaN         NaN
# 245                      NaN         NaN
# 246                      NaN         NaN
# 247                      NaN         NaN
# 248                      NaN         NaN
# 249                      NaN         NaN
# 250                      NaN         NaN
# 251                      NaN         NaN
# 252                      NaN         NaN
# 253                      NaN         NaN
# 254                      NaN         NaN
# 255                      NaN         NaN
# 256                      NaN         NaN
# 257                      NaN         NaN
# 258                      NaN         NaN
# 259                      NaN         NaN
# 260                      NaN         NaN
# 261                      NaN         NaN
# 262                      NaN         NaN
# 263                      NaN         NaN
# 264                      NaN         NaN
# 265                      NaN         NaN

# %%
new_name = {'Unnamed: 2' :'Country',
           'Energy Supply':'Energy Supply',
           'Energy Supply per capita':'Energy Supply per capita',
           'Renewable Electricity Production':'% Renewable'}

# %%
energy.rename(columns= new_name, inplace=True)

# %%
energy.tail()
# Out:
#     Country Energy Supply Energy Supply per capita % Renewable
# 261     NaN           NaN                      NaN         NaN
# 262     NaN           NaN                      NaN         NaN
# 263     NaN           NaN                      NaN         NaN
# 264     NaN           NaN                      NaN         NaN
# 265     NaN           NaN                      NaN         NaN

# %%
import pandas as pd
energy = pd.read_excel('Energy Indicators.xls', header= 16,usecols="C:F")
new_name = {'Unnamed: 2' :'Country',
           'Energy Supply':'Energy Supply',
           'Energy Supply per capita':'Energy Supply per capita',
           'Renewable Electricity Production':'% Renewable'}
energy.rename(columns= new_name, inplace=True)
energy
# Out:
#             Country Energy Supply Energy Supply per capita % Renewable
# 0               NaN    Petajoules               Gigajoules           %
# 1       Afghanistan           321                       10     78.6693
# 2           Albania           102                       35         100
# 3           Algeria          1959                       51     0.55101
# 4    American Samoa           ...                      ...    0.641026
# ..              ...           ...                      ...         ...
# 261             NaN           NaN                      NaN         NaN
# 262             NaN           NaN                      NaN         NaN
# 263             NaN           NaN                      NaN         NaN
# 264             NaN           NaN                      NaN         NaN
# 265             NaN           NaN                      NaN         NaN
#
# [266 rows x 4 columns]

# %%
energy = energy.drop(energy, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-202-6ef1e80c8add> in <module>
# ----> 1 energy = energy.drop(index=0, axis = 0)
#
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# c:\users\subha\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
energy = energy.drop(energy.index[0], axis = 0)
energy
# Out:
#                  Country Energy Supply Energy Supply per capita % Renewable
# 8    Antigua and Barbuda             8                       84           0
# 9              Argentina          3378                       79     24.0645
# 10               Armenia           143                       48     28.2361
# 11                 Aruba            12                      120     14.8707
# 12            Australia1          5386                      231     11.8108
# ..                   ...           ...                      ...         ...
# 229                  NaN           NaN                      NaN         NaN
# 230                  NaN           NaN                      NaN         NaN
# 231                  NaN           NaN                      NaN         NaN
# 233                  NaN           NaN                      NaN         NaN
# 234                  NaN           NaN                      NaN         NaN
#
# [225 rows x 4 columns]

# %%
# Out:
#                  Country Energy Supply Energy Supply per capita % Renewable
# 7               Anguilla             2                      136           0
# 8    Antigua and Barbuda             8                       84           0
# 9              Argentina          3378                       79     24.0645
# 10               Armenia           143                       48     28.2361
# 11                 Aruba            12                      120     14.8707
# ..                   ...           ...                      ...         ...
# 229                  NaN           NaN                      NaN         NaN
# 230                  NaN           NaN                      NaN         NaN
# 231                  NaN           NaN                      NaN         NaN
# 233                  NaN           NaN                      NaN         NaN
# 234                  NaN           NaN                      NaN         NaN
#
# [226 rows x 4 columns]
